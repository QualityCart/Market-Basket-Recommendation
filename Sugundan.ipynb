# %% [markdown]
# TF-IDF with Cosine Similarity
#
# Implemented by: Mr. Sugundan

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-24999d4a-78ad-4c87-8cff-5f0f0c12b465" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24999d4a-78ad-4c87-8cff-5f0f0c12b465">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load dataset
df = pd.read_csv("/content/amazon_products_with_images (1).csv")

df = df[['product_name','category','brand','description']].fillna('')

# Combine features
df['combined_features'] = (
    df['category'] + " " +
    df['brand'] + " " +
    df['description']
)

# TF-IDF
tfidf = TfidfVectorizer(stop_words='english')
matrix = tfidf.fit_transform(df['combined_features'])

# Cosine Similarity
similarity = cosine_similarity(matrix)

# --------------------------
# User Input
# --------------------------

search = input("Enter Product Name or Brand : ").lower()

# Find matching products
matches = df[df['product_name'].str.lower().str.contains(search) |
             df['brand'].str.lower().str.contains(search)]

if len(matches) == 0:
    print("No product found!")
    exit()

# Take first matched product
index = matches.index[0]

print("\nSelected Product\n")
print(df.iloc[index]['product_name'])

scores = list(enumerate(similarity[index]))
scores = sorted(scores, key=lambda x: x[1], reverse=True)

print("\nTop 5 Recommendations\n")

count = 0

for i, score in scores:

    if i == index:
        continue

    print(df.iloc[i]['product_name'])
    print("Brand :", df.iloc[i]['brand'])
    print("Category :", df.iloc[i]['category'])
    print("Similarity :", round(score,3))
    print("--------------------------------")

    count += 1

    if count == 5:
        break
# Out:
# Enter Product Name or Brand : boAt Airdopes 141
#
# Selected Product
#
# boAt Airdopes 141 Bluetooth Truly Wireless in Ear Earbuds with mic, 42H Playtime, Beast Mode(Low Latency Upto 80ms) for Gaming, ENx Tech, ASAP Charge, IWP, IPX4 Water Resistance (Bold Black)
#
# Top 5 Recommendations
#
# boAt Airdopes 181 in-Ear True Wireless Earbuds with ENx  Tech, Beast  Mode(Low Latency Upto 60ms) for Gaming, with Mic, ASAP  Charge, 20H Playtime, Bluetooth v5.2, IPX4 & IWP (Cool Grey)
# Brand : boAt
# Category : Charging
# Similarity : 0.578
# --------------------------------
# boAt Airdopes 191G True Wireless Earbuds with ENx™ Tech Equipped Quad Mics, Beast™ Mode(Low Latency- 65ms) for Gaming, 2x6mm Dual Drivers, 30H Playtime, IPX5, IWP™, Appealing Case LEDs(Sport Blue)
# Brand : boAt
# Category : Headphones
# Similarity : 0.515
# --------------------------------
# ...
